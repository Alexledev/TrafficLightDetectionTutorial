# %%
import cv2
import numpy as np
import os

# %%
def procRPLTRlabelData(dataList, h, w):
    data = np.array(dataList)
    data = np.unique(data, axis=0)
    data = data[:, :5]
    
    print(data)
    
    labels = []
    
    for row in data:
        cls, xMin, yMin, xMax, yMax = row
    
        xCenter = ((xMin + xMax) / 2) / w
        yCenter = ((yMin + yMax) / 2) / h
        bw = (xMax - xMin) / w
        bh = (yMax - yMin) / h
    
        labels.append(f"{int(cls)} {xCenter} {yCenter} {bw} {bh}")

    return labels

# %%
def makeImgLabelPair(numTag, img, labelNP, folderName):
    h, w, _ = img.shape
    labelList = labelNP.tolist()

    labels = procRPLTRlabelData(labelList, h, w)

    os.makedirs(f"{folderName}/labels", exist_ok=True)
    os.makedirs(f"{folderName}/images", exist_ok=True)
    
    with open(f"{folderName}/labels/{numTag}.txt", "w") as f:
        f.write("\n".join(labels))
    
    cv2.imwrite(f"{folderName}/images/{numTag}.png", img)

# %%
def runProcessing():
    for i in range(700):  # 0 → 499
        numTag = str(i).zfill(4)
    
        imagePath = fr"C:/PROJECTS/RoverDudeWS/ReplicatorOutput/rgb_{numTag}.png"
        labelPath = fr"C:/PROJECTS/RoverDudeWS/ReplicatorOutput/bounding_box_2d_tight_{numTag}.npy"
        
        img = cv2.imread(imagePath)
        data = np.load(labelPath)

        if data is None or len(data) == 0:
            print(f"No data on {i}")
            continue
    
        makeImgLabelPair(numTag, img, data, "PrepData2")

        print(f"---{i}---")

# %%
runProcessing()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 runProcessing()
#
# Cell In[4], line 9, in runProcessing()
#       6 labelPath = f"ReplicatorOutput/bounding_box_2d_tight_{numTag}.npy"
#       8 img = cv2.imread(imagePath)
# ----> 9 data = np.load(labelPath)
#      11 if data is None or len(data) == 0:
#      12     print(f"No data on {i}")
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ReplicatorOutput/bounding_box_2d_tight_0000.npy'
